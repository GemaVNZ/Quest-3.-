# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\laura\anaconda3\lib\site-packages (2.32.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laura\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laura\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\laura\anaconda3\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laura\anaconda3\lib\site-packages (from requests) (2024.8.30)

# %%
import requests
import json

base_url = "https://www.carboninterface.com/api/v1"
api_key = "vJxBNzJxpgaG4mS9wrqTNw"


headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}
data = {
    "type": "flight",
    "passengers": 2,
    "legs": [
        {"departure_airport": "MAD", "destination_airport": "CDG"},
        {"departure_airport": "CDG", "destination_airport": "MAD"}
    ]
}

response = requests.post(f"{base_url}/estimates", headers=headers, data=json.dumps(data))

if response.status_code == 201:
    result = response.json()
    print("Estimación de emisiones de carbono para vuelo España-Francia:")
    print(f"ID de la estimación: {result['data']['id']}")
    print(f"Tipo: {result['data']['type']}")
    print(f"Atributos:")
    print(f"  Pasajeros: {result['data']['attributes']['passengers']}")
    # print(f"  Emisiones en libras: {result['data']['attributes']['carbon_lb']}")
    print(f"  Emisiones en kilogramos: {result['data']['attributes']['carbon_kg']}")
    print(f"  Emisiones en toneladas métricas: {result['data']['attributes']['carbon_mt']}")
    print(f"  Distancia en km: {result['data']['attributes']['distance_value']}")
else:
    print(f"Error en la solicitud: {response.status_code}")
    print(response.text)
# Out:
# Estimación de emisiones de carbono para vuelo España-Francia:
# ID de la estimación: 65115a79-892e-40b6-a4cc-cbb3a58a8c81
# Tipo: estimate
# Atributos:
#   Pasajeros: 2
#   Emisiones en libras: 365.98
#   Emisiones en kilogramos: 166.01
#   Emisiones en toneladas métricas: 0.17
#   Distancia en millas: 1164.29

# %%
response = requests.get(f"{base_url}/vehicle_makes", headers=headers)

if response.status_code == 200:
    vehicle_makes = response.json()
    for make in vehicle_makes:
        print(f"Marca: {make['data']['attributes']['name']}, ID: {make['data']['id']}")
else:
    print("Error al obtener las marcas de vehículos")
# Out:
# Marca: Alfa Romeo, ID: 5f266411-5bb1-4b91-b044-9707426df630
# Marca: Ferrari, ID: 4c1e16e1-7967-4394-b3cb-15f4577dffa1
# Marca: Dodge, ID: c0d79b67-76e8-442d-b105-2c73501948a9
# Marca: Subaru, ID: c983d62d-e823-4bfb-92a8-45d161be1fe1
# Marca: Toyota, ID: 2b1d0cd5-59be-4010-83b3-b60c5e5342da
# Marca: Volkswagen, ID: 86e1e7df-57c2-4753-9f7f-c1a2a1529942
# Marca: Volvo, ID: 1c2a69d5-54d3-4796-a424-ffbdf8b538d1
# Marca: Audi, ID: b5a8c75a-c224-4660-b110-73d5ca0c3998
# Marca: BMW, ID: de66a011-eafe-4191-aee7-5c01b894e905
# Marca: Buick, ID: 29c8b9d7-be12-4ff8-b440-f2c5deb67384
# Marca: Cadillac, ID: f72507b2-0fd9-437c-9210-74551945785e
# Marca: Chevrolet, ID: ec2508b8-627e-418d-9813-c52d28061be4
# Marca: Chrysler, ID: 2c47505b-fa07-4e49-a479-0b35563a973c
# Marca: CX Automotive, ID: 58399166-9471-4659-9610-6f442bb7db60
# Marca: Genesis, ID: 2f1bed57-f1ff-4479-9c22-5d941eba1f5f
# Marca: Karma, ID: ef216d48-2b4b-417c-8d17-41cc7ccb0be9
# Marca: Koenigsegg, ID: 9619bbef-2f95-47c8-b322-0def4902ea93
# Marca: Aurora Cars Ltd, ID: 3f430b34-57d1-470f-9436-107391ade7b4
# Marca: RUF Automobile, ID: 1184c1ff-58cb-4e6d-9a25-d91868a0bb32
# Marca: Dacia, ID: 8276a2a9-7f9b-4683-9925-a680642a3a13
# Marca: STI, ID: 039e4fbc-992f-4ef9-b84a-96e95bb23e75
# Marca: Daihatsu, ID: 0df549bb-dfe5-4b77-9032-3b1fbcbe675b
# Marca: Polestar Automotive USA Inc., ID: 44538296-4bd6-4fdc-9c48-efb5875e5f47
# Marca: JBA Motorcars, Inc., ID: b8cca3b9-f8c2-4357-846b-1aa715468128
# Marca: Grumman Allied Industries, ID: a6aa0b78-d150-4e8f-adf5-4a6da5f25ae5
# Marca: Environmental Rsch and Devp Corp, ID: 574d4b85-1d90-46c2-b4eb-09c1fd06ebe8
# Marca: Evans Automobiles, ID: 69468c6c-524c-452d-922f-1e709ee556db
# Marca: Laforza Automobile Inc, ID: 2c3bfe76-51b5-466f-bd72-b0d3bab07b51
# Marca: General Motors, ID: 508dc614-249a-4789-9b1a-2f0c9ec26701
# Marca: Consulier Industries Inc, ID: 722c1475-3b72-410e-8adb-84bd0e0646e1
# Marca: Goldacre, ID: fb528008-a6cb-4583-b65a-8eddf1e8410e
# Marca: Isis Imports Ltd, ID: c66e4564-8655-43bd-846f-85aaf3ce3363
# Marca: PAS Inc - GMC, ID: 1e99e971-e2e1-4c55-b2e3-eb16b66cc639

# %%
make_id = "35a59281-c4e0-4340-9ec9-f58ed4ca7435"
response = requests.get(f"{base_url}/vehicle_makes/{make_id}/vehicle_models", headers=headers)
if response.status_code == 200:
    vehicle_models = response.json()
    for model in vehicle_models:
        print(f"Modelo: {model['data']['attributes']['name']}, ID: {model['data']['id']}")
else:
    print(f"Error al obtener los modelos: {response.status_code}")
# Out:
# Error al obtener los modelos: 404

# %%
# TESLA COCHE ELECTRICO
data = {
    "type": "vehicle",
    "distance_unit": "km",
    "distance_value": 2556, 
    "vehicle_model_id": "4f793e3a-931b-4134-ba96-6a75de006a43"  
}

response = requests.post(f"{base_url}/estimates", headers=headers, data=json.dumps(data))
if response.status_code == 201:
    result = response.json()
    print("Estimación de emisiones de carbono para vehículo:")
    print(f"ID de la estimación: {result['data']['id']}")
    print(f"Tipo: {result['data']['type']}")
    print(f"Atributos:")
    print(f"  Distancia: {result['data']['attributes']['distance_value']} {result['data']['attributes']['distance_unit']}")
    print(f"  Modelo de vehículo: {result['data']['attributes']['vehicle_model']}")
    print(f"  Emisiones en libras: {result['data']['attributes']['carbon_lb']}")
    print(f"  Emisiones en kilogramos: {result['data']['attributes']['carbon_kg']}")
    print(f"  Emisiones en toneladas métricas: {result['data']['attributes']['carbon_mt']}")
else:
    print(f"Error en la solicitud: {response.status_code}")
    print(response.text)
